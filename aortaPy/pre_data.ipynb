# %%
import DataLoader

# %%
import os
import numpy as np
import cv2

# %%
datadir = "/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/"

# %%
train_dir = "/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/train"
val_dir = "/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/val"
test_dir = "/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/test"

dataset_train = DataLoader.Dataset()
dataset_test = DataLoader.Dataset()
dataset_val = DataLoader.Dataset()

dataset_train.load_dataset(train_dir)
dataset_test.load_dataset(test_dir)
dataset_val.load_dataset(val_dir)
# Out:
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/train
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/test
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/val

# %%
dataset_val.image_info
# Out:
# {'35_event_14': ['35_event',
#   '/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/val/35/35_event/血管分叉层面/14.dcm',
#   0],
#  '35_event_10': ['35_event',
#   '/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/val/35/35_event/血管分叉层面/10.dcm',
#   0],
#  '35_event_11': ['35_event',
#   '/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/val/35/35_event/血管分叉层面/11.dcm',
#   0],
#  '35_event_13': ['35_event',
#   '/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/val/35/35_event/血管分叉层面/13.dcm',
#   0],
#  '35_event_12': ['35_event',
#   '/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/val/35/35_event/血管分叉层面/12.dcm',
#   0],
#  '35_event_9': ['35_event',
#   '/Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41对/val/35/35_event/血管分叉层面/9.dcm',
#   0],
#  '35_event_8': ['35_event',
# ...

# %%
i = dataset_train.image_id[2]
img, class_id = dataset_train.load_image(i)
case, _, iid = i.split("_")
print(np.max(img),class_id,case, iid)
# Out:
# 1654 0 32 11

# %%
for i in dataset_train.image_id:
    img, class_id = dataset_train.load_image(i)
    case, _, iid = i.split("_")
    out_path = os.path.join(datadir, "train", str(iid), str(class_id))
    if not os.path.exists(out_path): os.makedirs(out_path)
    out_img = os.path.join(out_path,"{}.png".format(case))
    cv2.imwrite(out_img, img, [int(cv2.IMWRITE_PNG_COMPRESSION), 0])
    print(out_img)
# Out:
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/14/0/32.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/10/0/32.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/11/0/32.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/13/0/32.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/12/0/32.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/9/0/32.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/8/0/32.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/6/0/32.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/7/0/32.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/5/0/32.png
# ...

# %%
for i in dataset_val.image_id:
    img, class_id = dataset_val.load_image(i)
    case, _, iid = i.split("_")
    out_path = os.path.join(datadir, "train", str(iid), str(class_id))
    if not os.path.exists(out_path): os.makedirs(out_path)
    out_img = os.path.join(out_path,"{}.png".format(case))
    cv2.imwrite(out_img, img, [int(cv2.IMWRITE_PNG_COMPRESSION), 0])
    print(out_img)
# Out:
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/14/0/35.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/10/0/35.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/11/0/35.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/13/0/35.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/12/0/35.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/9/0/35.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/8/0/35.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/6/0/35.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/7/0/35.png
# /Users/nikki/Documents/xyu_iterms/aorta_classification/aortaData/20191108_41/train/5/0/35.png
# ...
